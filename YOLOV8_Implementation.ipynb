# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Standard output is '/device:GPU:0'
# Out:
# '/device:GPU:0'

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.1/749.1 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 39.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 52.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 721.1 kB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/nvidia-cublas-cu12/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.9 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="N8nTFF91YIzkcREXpeOd")
project = rf.workspace("tanvimahajan").project("shop_stock_dataset")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to SHOP_STOCK_DATASET-1 in yolov5pytorch:: 100%|██████████| 10836/10836 [00:02<00:00, 5341.03it/s]

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data="/content/SHOP_STOCK_DATASET-1/data.yaml" \
epochs=1 \
imgsz=640

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data="/content/SHOP_STOCK_DATASET-1/data.yaml" \
epochs=10 \
imgsz=640

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data="/content/SHOP_STOCK_DATASET-1/data.yaml" \
epochs=50 \
imgsz=640
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data="/content/SHOP_STOCK_DATASET-1/data.yaml" \
epochs=100 \
imgsz=640

# %%
#DONT TOUCH BELOW IT

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data="/content/SHOP_STOCK_DATASET-1/data.yaml" \
epochs=100 \
imgsz=640
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model="/content/runs/detect/train2/weights/best.pt" \
data="/content/SHOP_STOCK_DATASET-1/data.yaml"
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11129454 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/SHOP_STOCK_DATASET-1/valid/labels.cache... 1105 images, 1 backgrounds, 0 corrupt: 100% 1105/1105 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 70/70 [00:17<00:00,  3.97it/s]
#                    all       1105       1123      0.996       0.99      0.992      0.932
#                  Ariel       1105         87      0.975      0.908      0.967      0.746
#              Coca Cola       1105        121      0.998      0.992      0.995      0.927
#                Colgate       1105        130      0.998          1      0.995      0.927
#                  Fanta       1105        117      0.998          1      0.995      0.962
#                Kurkure       1105        115      0.998          1      0.995      0.962
# ...
